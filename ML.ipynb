# %%
#import data using pandas
from sklearn.tree import DecisionTreeClassifier
import pandas as pd
music_data=pd.read_csv("CS98XClassificationTest.csv")

# %%
music_data
# Out:
#       Id                                              title  \
# 0    454                                            Pump It
# 1    455  Circle of Life - From "The Lion King"/Soundtra...
# 2    456             We Are The Champions - Remastered 2011
# 3    457                              Insomnia - Radio Edit
# 4    458                                This Eve of Parting
# ..   ...                                                ...
# 108  563                                         Candy Shop
# 109  564                Dragostea Din Tei - Italian Version
# 110  565                          Big Poppa - 2005 Remaster
# 111  566                       YMCA - Original Version 1978
# 112  567                                 Livin' On A Prayer
#
#                    artist  year  bpm  nrgy  dnce  dB  live  val  dur  acous  \
# 0     The Black Eyed Peas  2005  154    93    65  -3    75   74  213      1
# 1              Elton John  1994  161    39    30 -15    11   14  292     26
# 2                   Queen  1977   64    46    27  -7    12   18  179     38
# 3               Faithless  2010  127    92    71  -9    37   53  216      6
# 4           John Hartford  2018  115    46    56 -12    21   34  153     18
# ..                    ...   ...  ...   ...   ...  ..   ...  ...  ...    ...
# 108               50 Cent  2005  125    57    61  -8    38   76  209      3
# 109                O-Zone  2010  130    89    67  -6    10   80  215      4
# 110  The Notorious B.I.G.  1994   84    58    78  -7    14   76  253     43
# 111        Village People  1978  127    97    72  -5    12   73  287      6
# 112              Bon Jovi  1986  123    89    53  -4    29   80  249      8
#
#      spch  pop
# 0      18   72
# 1       3   59
# 2       3   76
# 3       4   50
# 4       3   44
# ..    ...  ...
# 108    47   78
# 109     3   44
# 110    27   74
# 111    14   71
# 112     3   83
#
# [113 rows x 14 columns]

# %%
#split data set into input and output sets

x=music_data.drop(columns=['pop'])

# %%
x
# Out:
#       Id                                              title  \
# 0    454                                            Pump It
# 1    455  Circle of Life - From "The Lion King"/Soundtra...
# 2    456             We Are The Champions - Remastered 2011
# 3    457                              Insomnia - Radio Edit
# 4    458                                This Eve of Parting
# ..   ...                                                ...
# 108  563                                         Candy Shop
# 109  564                Dragostea Din Tei - Italian Version
# 110  565                          Big Poppa - 2005 Remaster
# 111  566                       YMCA - Original Version 1978
# 112  567                                 Livin' On A Prayer
#
#                    artist  year  bpm  nrgy  dnce  dB  live  val  dur  acous  \
# 0     The Black Eyed Peas  2005  154    93    65  -3    75   74  213      1
# 1              Elton John  1994  161    39    30 -15    11   14  292     26
# 2                   Queen  1977   64    46    27  -7    12   18  179     38
# 3               Faithless  2010  127    92    71  -9    37   53  216      6
# 4           John Hartford  2018  115    46    56 -12    21   34  153     18
# ..                    ...   ...  ...   ...   ...  ..   ...  ...  ...    ...
# 108               50 Cent  2005  125    57    61  -8    38   76  209      3
# 109                O-Zone  2010  130    89    67  -6    10   80  215      4
# 110  The Notorious B.I.G.  1994   84    58    78  -7    14   76  253     43
# 111        Village People  1978  127    97    72  -5    12   73  287      6
# 112              Bon Jovi  1986  123    89    53  -4    29   80  249      8
#
#      spch
# 0      18
# 1       3
# 2       3
# 3       4
# 4       3
# ..    ...
# 108    47
# 109     3
# 110    27
# 111    14
# 112     3
#
# [113 rows x 13 columns]

# %%
y=music_data['pop']

# %%
y
# Out:
# 0      72
# 1      59
# 2      76
# 3      50
# 4      44
#        ..
# 108    78
# 109    44
# 110    74
# 111    71
# 112    83
# Name: pop, Length: 113, dtype: int64

# %%
# select a learning algorithm
model=DecisionTreeClassifier()

# %%
# Drop the 'top genre' column before one-hot encoding
class_train_encoded = class_train.drop('top genre', axis=1)

# Perform one-hot encoding on the categorical columns
class_train_encoded = pd.get_dummies(class_train_encoded, columns=['top genre'])

# Select any binary column created by one-hot encoding (adjust if needed)
top_genre_column = class_train_encoded.columns[13]

# Select features using chi-squared test
X = class_train_encoded.drop(['top genre', top_genre_column], axis=1)
y = class_train_encoded['top genre']

# Train the model
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 5
#       2 class_train_encoded = class_train.drop('top genre', axis=1)
#       4 # Perform one-hot encoding on the categorical columns
# ----> 5 class_train_encoded = pd.get_dummies(class_train_encoded, columns=['top genre'])
#       7 # Select any binary column created by one-hot encoding (adjust if needed)
#       8 top_genre_column = class_train_encoded.columns[13]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/reshape/encoding.py:146, in get_dummies(data, prefix, prefix_sep, dummy_na, columns, sparse, drop_first, dtype)
#     144     raise TypeError("Input must be a list-like for parameter `columns`")
#     145 else:
# --> 146     data_to_encode = data[columns]
#     148 # validate prefixes and separator to avoid silently dropping cols
#     149 def check_len(item, name):
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6130, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6128     if use_interval_msg:
#    6129         key = list(key)
# -> 6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['top genre'], dtype='object')] are in the [columns]"
